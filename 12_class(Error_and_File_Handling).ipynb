# %%
print("logic1")
print("logic2")

l1 : list[int] = [1,2,3]

try:
    print(5/2)
    print(l1[0])
    print(xyz) # error
except (ZeroDivisionError,IndexError,NameError):
    print("Zerro Division Error!")
print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 2.5
# 1
# Zerro Division Error!
# logic4
# logic5

# %%
print("logic1")
print("logic2")

l1 : list[int] = [1,2,3]

try:
    print(5/4)
    print(l1[0])# Error
    # print(xyz) # error
    open("aa.txt")
except (ZeroDivisionError):
    print("Zerro Division Error!")
except IndexError:
    print("Index Error")
except NameError:
    print("Name not defined")
except:
    print("Some thing is wrong!")


print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 1.25
# 1
# Some thing is wrong!
# logic4
# logic5

# %%
try:
    print(age)
    # print(l1[200])
except Exception as e:
    print(f"Some thing is wrong!\n{e}")
# Out:
# Some thing is wrong!
# name 'age' is not defined

# %%
class StudentCard():
    def __init__(self, roll_no:int, name:str, age:int) -> None:
        if age < 18 or age > 60:
            raise StudentAgeError("Your are not eligible for this program!")
        self.roll_no = roll_no
        self.name = name
        self.age = age


class StudentAgeError(Exception):# custom error class
    pass

studen1 = StudentCard(1,"Qasim",30)

print(studen1.name, studen1.roll_no, studen1.age)
# Out:
# Qasim 1 30

# %% [markdown]
# ## File Handling
#
# https://www.geeksforgeeks.org/reading-writing-text-files-python/

# %%
data = open("abc.txt")
data
# Out:
# <_io.TextIOWrapper name='abc.txt' mode='r' encoding='utf-8'>

# %%
[i for i in dir(data) if "__" not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
from typing import TextIO
type(data)

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())
# Out:
# hello file

# %%
from typing import TextIO

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())

data.close() # close connectivity
# Out:
# hello file

# %%
with open("./abc.txt") as file: 
    print(type(file))
    print(file.read())

print("Pakistan zinda bad!")
# Out:
# <class '_io.TextIOWrapper'>
# hello file
# line 2
# Pakistan zinda bad!

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readlines()[1]) #
# Out:
# <class '_io.TextIOWrapper'>
# line 2

# %%
with open("./abc.txt", 'r') as file:  # type: TextIO
    print(file.read())
    file.write("Pakistan zinda bad")
    print(file.read())
# Out:
# hello file
# line 2Pakistan zinda badPakistan zinda bad
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# c:\Users\ghulam.ghaus\Desktop\office 2019\p\12_class.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt", 'r') as file:  # type: TextIO
#       <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     file.write("Pakistan zinda bad")
#       <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     print(file.read())
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt", 'w') as file:  # type: TextIO
    print(file.read())
    file.write("Pakistan zinda bad")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# c:\Users\ghulam.ghaus\Desktop\office 2019\p\12_class.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt", 'w') as file:  # type: TextIO
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
#       <a href='vscode-notebook-cell:/c%3A/Users/ghulam.ghaus/Desktop/office%202019/p/12_class.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     file.write("Pakistan zinda bad")
#
# UnsupportedOperation: not readable

# %%
with open("./abc1.txt", 'w') as file:  # type: TextIO
    file.write("Pakistan zinda bad")

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())

    file.write("WE love our country!")

    print("After",file.read())
    print(file.read())
# Out:
# Pakistan zinda badWE love our country!WE love our country!WE love our country!
# After

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())

    file.write("WE love our country!")
    file.seek(0)

    print("After",file.read())
# Out:
# Pakistan zinda badWE love our country!WE love our country!WE love our country!WE love our country!
# After Pakistan zinda badWE love our country!WE love our country!WE love our country!WE love our country!WE love our country!

# %%
with open("./abc1.txt", 'rb+') as file:  # type: TextIO
    print(file.read())
    # file.write("line3") 


# if file not exist then it will create new file
# Out:
# b'Pakistan zinda badWE love our country!WE love our country!WE love our country!WE love our country!WE love our country!'

# %% [markdown]
# ## read some real world data files
#
#    * image
#    * csv
#    * live camera

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv("./data.csv")

df
# Out:
#    id            name education
# 0   1         Sir Zia    Master
# 1   2        Sir Inam    Master
# 2   3  Muhammad Qasim      MSDS

# %%
import pandas as pd

df : pd.DataFrame = pd.read_excel("demo.xlsx")

df
# Out:
#    id            name education
# 0   1         Sir Zia    Master
# 1   2        Sir Inam    Master
# 2   3  Muhammad Qasim      MSDS
# 3   4       Dr, Noman       PHD

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread("img1.png")# covert into numpy array

plt.imshow(img)

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./mypdf.pdf")
pages
# Out:
# ['Pakistan\nzinda\nbad', 'We\nlove\nour\ncountry', 'PIAIC']
